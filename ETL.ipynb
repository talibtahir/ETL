# %%
print("Hello Talib")
# Out:
# Hello Talib

# %%
import psycopg2
import pandas as pd 


conn = psycopg2.connect(
    host = "192.168.101.190",
    database = "postgres",
    user = "postgres",
    password = "postgres",
    port = 5432
)

curr = conn.cursor()
query = "select * from emp;"
df = pd.read_sql(query, conn)

path = r"E:\study with me\power Bi\global_superstore.csv"
# with open(path, "r", encoding="utf-8") as f:
#     for _ in range(5): 
#         print(f.readline())
# Out:
# C:\Users\Work\AppData\Local\Temp\ipykernel_1596\3462685572.py:15: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)

# %%
df
# Out:
#    id   name
# 0   2  Aatif
# 1   1   fini

# %%
# this method is incorrect 
try: 
    with open(path, "r", encoding="utf-8") as f:
        curr.copy_expert(
            """
            COPY global_suberstore
            from STDIN
            WITH CSV HEADER
            DELIMITER ','
            """,
            f
        )
    conn.commit()
except Exception as e:
    conn.rollback()
    print("Copy failed ! ")
    print(e)
finally:
    curr.close()
# Out:
# Copy failed !
# current transaction is aborted, commands ignored until end of transaction block

# %% [markdown]
# # tomorrow taks is create table structure using SQL

# %%
df = pd.read_csv
